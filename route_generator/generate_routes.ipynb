# %% [markdown]
# <h2>Generating climbing route names with RNN</h2>
#
# This project is a variation on the following tutorial: [Text generation with an RNN](https://www.tensorflow.org/tutorials/text/text_generation)
#
# I generate rock climbing route names character by character. Training data was found on [kaggle](https://www.kaggle.com/dcohen21/8anu-climbing-logbook).

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers.experimental import preprocessing
import os
import time

# %%
df = pd.read_csv('ascent.csv')
# Out:
# /Users/vincentfortin/opt/anaconda3/envs/env_website/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
engl_countries = ['USA', 'GBR']

# %%
df_engl = df[df['country'].isin(engl_countries)].copy()

# %%
df_engl = df_engl.groupby('name').agg({'name':len})

# %%
df_engl.columns = ['count']

# %%
df_engl.reset_index(inplace=True)

# %%
subset_df = df_engl[df_engl['count']>9].copy()
print(len(subset_df.index))
plt.hist(subset_df['count'],bins=100)
plt.show()
# Out:
# 12770

# %%
route_names = subset_df['name']

# %%
route_names = [x.replace("'",'') for x in route_names if len(str(x).split())>1]

# %%
len(route_names)
# Out:
# 9762

# %%
len_list = [len(x) for x in route_names]
max_len = max(len_list)

# %%
route_names = [x+(' '*(max_len-len(x))) for x in route_names]

# %%
route_names
# Out:
# ['#2 Arete                                          ',
#  'v7 above longshot                                 ',
#  '1/2 Route                                         ',
#  '100 Proof Roof                                    ',
#  '100 Years of Solitude                             ',
#  '100% Columbian                                    ',
#  '1000 Shades of Green                              ',
#  '14 Carat                                          ',
#  '18 Inch Nail                                      ',
#  '2,000 and Beyond                                  ',
#  '20th Century Man                                  ',
#  '21 run                                            ',
#  '22 Chambers                                       ',
#  '245 North                                         ',
#  '25 Cents                                          ',
#  '27 Years of Climbing                              ',
#  '3 AM crack                                        ',
#  '3 Weeks                                           ',
#  '3 weeks                                           ',
#  '30 Seconds Over Potash                            ',
#  '30th Birthday Roof                                ',
#  '36 Chambers                                       ',
#  '4 on 6                                            ',
#  '40 Ounces of Justice                              ',
#  '40 oz to Freedom                                  ',
#  '41st Street                                       ',
#  '41st street                                       ',
#  '45 Traverse                                       ',
#  '45 wall traverse                                  ',
#  '5 Gallon Buckets                                  ',
#  '5% Tint                                           ',
#  '50 Something                                      ',
#  '50 Words for Crazy                                ',
#  '50 for 5                                          ',
#  '59" drillbitch                                    ',
#  '59 Drilll Bitch                                   ',
#  '5th Bolt Faith                                    ',
#  '5th of July                                       ',
#  '6-4 Arete                                         ',
#  '7 Ball                                            ',
#  '7 pm tv show                                      ',
#  '7-10 Split                                        ',
#  '700 Club                                          ',
#  '72 Hour Energy                                    ',
#  '8 Ball                                            ',
#  '8 Flake                                           ',
#  '80 feet of meat                                   ',
#  '9 Gallon Buckets                                  ',
#  '99 Heroin Balloons                                ',
#  '? No Name                                         ',
#  '? Unknown                                         ',
#  '? Unnamed                                         ',
#  '? name unknown                                    ',
#  'A B Top                                           ',
#  'A Big Round of Applause                           ',
#  'A Bigger Prize                                    ',
#  'A Bigger Splash                                   ',
#  'A Bigger Splash Direct                            ',
#  'A Bigger Tail                                     ',
#  'A Birthing Experience                             ',
#  'A Bit Slopey                                      ',
#  'A Bloody Lineage                                  ',
#  'A Bobcat in the Kiparoo                           ',
#  'A Boy Named Sue                                   ',
#  'A Brief History of Climb                          ',
#  'A Case of Mistaken Identity                       ',
#  'A Day in the Life                                 ',
#  'A Day in the Wife                                 ',
#  'A Face In the Crowd                               ',
#  'A Face in the Crowd                               ',
#  'A Face in the Crowd (Sit)                         ',
#  'A Farewell to Arms                                ',
#  'A Fist Full of Beagles                            ',
#  'A Fragile Term                                    ',
#  'A Good Day for Swiss Crisp Mix                    ',
#  'A Little Extra                                    ',
#  'A Little Extra Direct Start                       ',
#  'A Little More John Wayne                          ',
#  'A Long Road Home                                  ',
#  'A Man in Every Pot                                ',
#  'A Maze of Death                                   ',
#  'A Minor                                           ',
#  'A New Pair of Glasses                             ',
#  'A Northern Soul                                   ',
#  'A Portrait of the Artist as a Young Man           ',
#  'A River Runs Through It                           ',
#  'A Scanner Darkly                                  ',
#  'A Stirring of Air                                 ',
#  'A Tall Cool One                                   ',
#  'A Thousand Churches                               ',
#  'A Touch of Tango                                  ',
#  'A Wave New World                                  ',
#  'A Week with Pete                                  ',
#  'A bigger splash direct                            ',
#  'A boy named Sue                                   ',
#  'A day in the wife                                 ',
#  'A face in the crowd                               ',
#  'A farewell To arms                                ',
#  'A little Extra                                    ',
#  'AC Devil Dog                                      ',
#  'Ab Lounge                                         ',
#  'Ab Master                                         ',
#  'Abandon Ship                                      ',
#  'Abominable Snowman                                ',
#  'About Face                                        ',
#  'Absolute Zero                                     ',
#  'Access Denied                                     ',
#  'Ace in the Hole                                   ',
#  'Ace of Spades                                     ',
#  'Ache Ball                                         ',
#  'Achilles Lauro                                    ',
#  'Acid House                                        ',
#  'Acid Jazz Disco                                   ',
#  'Acid Mother Temple - Face Melter Roof             ',
#  'Acid Wash                                         ',
#  'Acid Wash Right                                   ',
#  'Acid Wash Right Stand                             ',
#  'Acid Wash right                                   ',
#  'Acid wash                                         ',
#  'Acid wash right                                   ',
#  'Acoustic Elvis                                    ',
#  'Acrophobiacs Anonymous                            ',
#  'Across the Choss                                  ',
#  'Across the Tracks                                 ',
#  'Across the Universe                               ',
#  'Action Candy                                      ',
#  'Action Figure                                     ',
#  'Action Indirect                                   ',
#  'Action Jackson                                    ',
#  'Action Over Apathy                                ',
#  'Action figure                                     ',
#  'Actual Edge of Gumby                              ',
#  'Adam Taylor Arete                                 ',
#  'Adamantium sit start                              ',
#  'Added Planet                                      ',
#  'Addiction to Friction                             ',
#  'Adios Amigos                                      ',
#  'Adjust Your Attitude                              ',
#  'Admiral Nelson                                    ',
#  'Adult Swim                                        ',
#  'Adults Only                                       ',
#  'Advanced Birding                                  ',
#  'Africa Arete                                      ',
#  'African Arete                                     ',
#  'African Herbman                                   ',
#  'After Party Arete                                 ',
#  'After Seven                                       ',
#  'After Six                                         ',
#  'Afternoon Buzz                                    ',
#  'Afternoon Delight                                 ',
#  'Against All Cobbs                                 ',
#  'Against Humanity                                  ',
#  'Against Humanity Low                              ',
#  'Against Humanity Right                            ',
#  'Against Nature                                    ',
#  'Against The Grain                                 ',
#  'Against humanity right                            ',
#  'Against the Grain                                 ',
#  'Against the grain                                 ',
#  'Agent Orange                                      ',
#  'Agent Provocateur                                 ',
#  'Agent orange                                      ',
#  'Agent orange stand                                ',
#  'Aggro Monkey                                      ',
#  'Agony of Defeat                                   ',
#  'Ahwahnee Arete                                    ',
#  'Aid Route                                         ',
#  'Air Flash Gordon                                  ',
#  'Air Guitar                                        ',
#  'Air Jesus                                         ',
#  'Air Jordan                                        ',
#  'Air Loopis                                        ',
#  'Air Ride Equipped                                 ',
#  'Air and Pleasant Danger                           ',
#  'Air-Ride Equipped                                 ',
#  'Als Attic                                         ',
#  'Als Diner                                         ',
#  'Als diner                                         ',
#  'Alabama Tiller                                    ',
#  'Alarm Clock Awakening                             ',
#  'Alcove Center                                     ',
#  'Alex Patterson                                    ',
#  'Alf in a Blender                                  ',
#  'Alfred Hitchcock                                  ',
#  'Ali Babbler                                       ',
#  'Ali Bubba                                         ',
#  'Ali Bubba sit start                               ',
#  'Alien Baby                                        ',
#  'Alien Baby Left                                   ',
#  'Alien Face                                        ',
#  'Alien Semen Rash                                  ',
#  'Alien Writing                                     ',
#  'All Business                                      ',
#  'All Chalk and No Action                           ',
#  'All Cows Eat Grass                                ',
#  'All Ears                                          ',
#  'All Fired Up                                      ',
#  'All For V4                                        ',
#  'All Guns Blazing                                  ',
#  'All Hands To The Pump                             ',
#  'All Hands to the Pump                             ',
#  'All Hes Ever Gonna Have                           ',
#  'All Jazzed Up                                     ',
#  'All Nighter                                       ',
#  'All Nightmare Long                                ',
#  'All Quiet Direct                                  ',
#  'All The Right Moves                               ',
#  'All Things Considered                             ',
#  'All Thumbs                                        ',
#  'All Washed Up                                     ',
#  'All hands to the pump                             ',
#  'All the Idiots                                    ',
#  'All the Way                                       ',
#  'All the Way Baby                                  ',
#  'All the Wrong Reasons                             ',
#  'All the pretty horses                             ',
#  'All the way baby                                  ',
#  'Alma Blanca                                       ',
#  'Almost French                                     ',
#  'Almost Gothic                                     ',
#  'Almost Heaven                                     ',
#  'Almost Me                                         ',
#  'Almost but not Quite                              ',
#  'Alpha Centauri                                    ',
#  'Alpine Club                                       ',
#  'Already Forgotten                                 ',
#  'Altar Boys                                        ',
#  'Altered Scale                                     ',
#  'Alternative Optional Extra                        ',
#  'Alternative optional extra                        ',
#  'Always Keep It Loaded                             ',
#  'Always Lead The Possum                            ',
#  'Always Lead the Opossum                           ',
#  'Always Tomorrow                                   ',
#  'Always have the edge                              ',
#  'Alzheimers Onsight                                ',
#  'Amarillo Sunset                                   ',
#  'Amateur Series                                    ',
#  'Amazing Face                                      ',
#  'Amazing Gift                                      ',
#  'Amazing Grace                                     ',
#  'Amazing Little Halfboy                            ',
#  'Ament Arete                                       ',
#  'Ament arete                                       ',
#  'Americas Fit Homeless                             ',
#  'Americas Most Wanted                              ',
#  'American Beauty                                   ',
#  'American Crack                                    ',
#  'American Dream                                    ',
#  'American Express                                  ',
#  'American Flyers                                   ',
#  'American Gigolo                                   ',
#  'American Nirvana                                  ',
#  'American Pie                                      ',
#  'American Prayer                                   ',
#  'American Sportsman                                ',
#  'Americana Exotica                                 ',
#  'Americana exotica                                 ',
#  'Ames Low                                          ',
#  'Ammo Dump                                         ',
#  'An 80/20 Ratio                                    ',
#  'An Even Bigger Tail                               ',
#  'Anal Clenching Adventures                         ',
#  'Anal Intruder #10                                 ',
#  'Anarchy Rules                                     ',
#  'Anarchy in the UK                                 ',
#  'Anatomy Act                                       ',
#  'Anatomy act                                       ',
#  'Ancient Order of Freemarblers                     ',
#  'And the Bucket of Parts                           ',
#  'And the bucket of parts                           ',
#  'Andrew Boulder Prob                               ',
#  'Andrew Boulder Problem                            ',
#  'Andy Browns Wall                                  ',
#  'Andys Arete                                       ',
#  'Aneardon Low                                      ',
#  'Angel Deelite                                     ',
#  'Angel Delight                                     ',
#  'Angel Dyno                                        ',
#  'Angel Wings                                       ',
#  'Angel dyno                                        ',
#  'Anger Management                                  ',
#  'Angle of Attack                                   ',
#  'Angled Dangler                                    ',
#  'Angry Beaver                                      ',
#  'Angry Birds                                       ',
#  'Angry Itch                                        ',
#  'Angular Motion                                    ',
#  'Animal Acts                                       ',
#  'Animal Attack                                     ',
#  'Animal Farm                                       ',
#  'Animal Instinct                                   ',
#  'Animal Logic                                      ',
#  'Animal Magnetism                                  ',
#  'Animal Riots Activist                             ',
#  'Ankles Away                                       ',
#  'Annie Git Yer Drill                               ',
#  'Annie the Annihilator                             ',
#  'Anorexic Nerve Dance                              ',
#  'Another Doug Reed Route                           ',
#  'Another Notch in the Gun                          ',
#  'Another Toadside Attraction                       ',
#  'Another World                                     ',
#  'Ants Line                                         ',
#  'Anti Hero                                         ',
#  'Anti future plan                                  ',
#  'Ants Line                                         ',
#  'Any Major Dude                                    ',
#  'Any Which Way                                     ',
#  'Ape Drape                                         ',
#  'Apes on Acid                                      ',
#  'Apfel Strudel                                     ',
#  'Apocalypse 95                                     ',
#  'Apocalypse Later                                  ',
#  'Apocalypse Now                                    ',
#  'Apocalypse Prow                                   ',
#  'Apollo Reed                                       ',
#  'Apoplectic Chick from Missouri                    ',
#  'Appalachian Spring                                ',
#  'Appetite for Destruction                          ',
#  'Apple Bottom Jeans                                ',
#  'Apple turn overload                               ',
#  'Apprentice Prow                                   ',
#  'April Fools                                       ',
#  'Aqua Huck                                         ',
#  'Aquaduck Pocket                                   ',
#  'Aquatic Hitchhiker                                ',
#  'Arachonothera Direct                              ',
#  'Arc Minute                                        ',
#  'Arch Drude                                        ',
#  'Arch Drude Left                                   ',
#  'Arch Druid                                        ',
#  'Arch Enemies                                      ',
#  'Arch Enemy                                        ',
#  'Arch Rival                                        ',
#  'Archaic Migration                                 ',
#  'Architect Rally                                   ',
#  'Architects on Acid                                ',
#  'Are You Experienced?                              ',
#  'Are the Pies Fresh?                               ',
#  'Area of doubt                                     ',
#  'Arete Problem                                     ',
#  'Arete to Arete                                    ',
#  'Arizona Cowgirl                                   ',
#  'Arkansas Reality                                  ',
#  'Arm and Hammer                                    ',
#  'Armed Insurection                                 ',
#  'Armed and Dangerous                               ',
#  'Armed, Dangerous and Off My Medication            ',
#  'Armistice Day                                     ',
#  'Army of Darkness                                  ',
#  'Around the Corner                                 ',
#  'Around the Fur                                    ',
#  'Around the World                                  ',
#  'Arrested Development                              ',
#  'Arrowhead Arete                                   ',
#  'Arrowhead arete sit                               ',
#  'Art of Vogi                                       ',
#  'Art of Vogi Left                                  ',
#  'Art of the Vogi                                   ',
#  'Art of the Vogi Left                              ',
#  'As Hard As They Come                              ',
#  'As Hard as they Come                              ',
#  'As The Jerks Fly                                  ',
#  'As Wicked as it Seems                             ',
#  'As the Crows Fly                                  ',
#  'As the Jerks Fly                                  ',
#  'Asbury Park                                       ',
#  'Asheboros Steepest                                ',
#  'Asian Invasion                                    ',
#  'Aspen Grove                                       ',
#  'Asshole Arete                                     ',
#  'Assisted Living                                   ',
#  'Astro Zombies                                     ',
#  'Asylum Sika                                       ',
#  'Atheist Childhood                                 ',
#  'Athletes Die Young                                ',
#  'Atlas Shrugged                                    ',
#  'Atomic Cow                                        ',
#  'Atomic Energy                                     ',
#  'Atomic Gecko                                      ',
#  'Atomic Melvin                                     ',
#  'Atomic Stetson                                    ',
#  'Attack of the Staph                               ',
#  'Attitude Inspector                                ',
#  'Augustus Gloop                                    ',
#  'Aunt Jemimas Bisquick Thunderdome                 ',
#  'Aural Pleasure                                    ',
#  'Austin Powers                                     ',
#  'Austrian Ass Attack                               ',
#  'Austrian Oak                                      ',
#  'Authentic Battle Damage                           ',
#  'Authentic Battle Damage Stand                     ',
#  'Authentic Battle Damage stand                     ',
#  'Autobot Low                                       ',
#  'Autobot SDS                                       ',
#  'Autumn Fire                                       ',
#  'Avada Kedavra                                     ',
#  'Avalanche run                                     ',
#  'Avenging the Halswell                             ',
#  'Avian Flu                                         ',
#  'Axle Attack                                       ',
#  'Azzeed Jiz                                        ',
#  'B Cubed                                           ',
#  'B Cubed Right                                     ',
#  'B Flat                                            ',
#  'B-1 Bomber Dude                                   ',
#  'B1 Traverse                                       ',
#  'B2 Bomber                                         ',
#  'BRAWNY DYNO                                       ',
#  'Babelicious Redhead                               ',
#  'Babies with Rabies                                ',
#  'Babinski Sign                                     ',
#  'Baboo Baboo                                       ',
#  'Baby Bear                                         ',
#  'Baby Blue Eyes                                    ',
#  'Baby Brothers                                     ',
#  'Baby Face                                         ',
#  'Baby Fat                                          ',
#  'Baby Got Back                                     ',
#  'Baby Has a Bolt Gun                               ',
#  'Baby Hole                                         ',
#  'Baby Martini                                      ',
#  'Baby Rage                                         ',
#  'Baby Tomahawk                                     ',
#  'Bacardi Silver                                    ',
#  'Bachar Cracker                                    ',
#  'Bachar Problem                                    ',
#  'Bachar Problem Left                               ',
#  'Bachar Problem Right                              ',
#  'Back door to Paris                                ',
#  'Back in Black                                     ',
#  'Back in the Saddle                                ',
#  'Back in the saddle                                ',
#  'Back to the Future                                ',
#  'Backdoor Ass Attack                               ',
#  'Backdoor Man                                      ',
#  'Backdoor ass attack                               ',
#  'Backhoe Left                                      ',
#  'Backside Crack                                    ',
#  'Baco Bit                                          ',
#  'Bad Ass                                           ',
#  'Bad Cat                                           ',
#  'Bad Company                                       ',
#  'Bad Daze                                          ',
#  'Bad Faith                                         ',
#  'Bad Finger                                        ',
#  'Bad Genes                                         ',
#  'Bad Girls Get Spanked                             ',
#  'Bad Landing Roof                                  ',
#  'Bad Lip                                           ',
#  'Bad Moon Rising                                   ',
#  'Bad Religion                                      ',
#  'Bad landing boulder                               ',
#  'Bad lip                                           ',
#  'Badgering the Witness                             ',
#  'Baked Potato                                      ',
#  'Balance Beam                                      ',
#  'Balance beam                                      ',
#  'Balance in Nature                                 ',
#  'Balance of Power                                  ',
#  'Balcones Gigantes                                 ',
#  'Bald Eagle                                        ',
#  'Baldstones Traverse                               ',
#  'Baldwin Bash                                      ',
#  'Ball Scratcher                                    ',
#  'Banana Boy                                        ',
#  'Banana Dance                                      ',
#  'Banana Finger                                     ',
#  'Banana Finger Direct                              ',
#  'Banana Hammock                                    ',
#  'Banana Juice                                      ',
#  'Banana Reverse                                    ',
#  'Banana Split                                      ',
#  'Banana dance                                      ',
#  'Bang On                                           ',
#  'Bangers and mash                                  ',
#  'Bar Fly                                           ',
#  'Barbecue the Pope                                 ',
#  'Barbed Wire                                       ',
#  'Barbed Wire Beard                                 ',
#  'Barbed Wire Kisses                                ',
#  'Barbeque the Pope                                 ',
#  'Barbeque the pope                                 ',
#  'Barbwire and Lingerie                             ',
#  'Bare Metal Teen                                   ',
#  'Barefoot Sharma Arete                             ',
#  'Barefoot on Sacred Ground                         ',
#  'Barely Legal                                      ',
#  'Barfing Butterflies                               ',
#  'Barguest Direct                                   ',
#  'Bark Biter                                        ',
#  'Barking Spiders                                   ',
#  'Barn Door                                         ',
#  'Barnacle Bill                                     ',
#  'Barndoor Arete                                    ',
#  'Barney Rubble                                     ',
#  'Barrel Full of Monkeys                            ',
#  'Barrel Groove                                     ',
#  'Barrel Traverse                                   ',
#  'Barrio Traverse                                   ',
#  'Barry Kingsize                                    ',
#  'Baseboy direct                                    ',
#  'Bashers Problem                                   ',
#  'Bashers problem                                   ',
#  'Basketball Diaries                                ',
#  'Basketball Mantle                                 ',
#  'Bastard Stepchild                                 ',
#  'Bastard stepchild                                 ',
#  'Bastille Crack                                    ',
#  'Bat Roof                                          ',
#  'Bat Route                                         ',
#  'Bat roof                                          ',
#  'Bates (sit)                                       ',
#  'Bates Arete                                       ',
#  'Bates Eliminate                                   ',
#  'Bates Problem                                     ',
#  'Bathtub Mary                                      ',
#  'Bathtub mary                                      ',
#  'Batso Canal                                       ',
#  'Battaglias Backside                               ',
#  'Battaglias Bottom                                 ',
#  'Battery Life                                      ',
#  'Battle Cry                                        ',
#  'Battle for a Wounded Knee                         ',
#  'Battle of the Bulge                               ',
#  'Battle of the bulge                               ',
#  'Bawl and Chain                                    ',
#  'Bawl and chain                                    ',
#  'Bazooka Country                                   ',
#  'Bazooka Face                                      ',
#  'Bazooka Tooth                                     ',
#  'Be Flat                                           ',
#  'Be Like Mikey                                     ',
#  'Be Ruthless                                       ',
#  'Be awesome                                        ',
#  'Beach Arete                                       ',
#  'Beach Ball                                        ',
#  'Beach Bum                                         ',
#  'Beach Crack                                       ',
#  'Beach ball                                        ',
#  'Beached Whale                                     ',
#  'Beak Mantle                                       ',
#  'Beak Traverse                                     ',
#  'Beam and Coke                                     ',
#  'Bean Fiddler                                      ',
#  'Bean fiddler                                      ',
#  'Bear Claw                                         ',
#  'Bear Hug                                          ',
#  'Bear Hug Arete                                    ',
#  'Bear Hug Mantle                                   ',
#  'Bear Mountain Picnic                              ',
#  'Bear Toss                                         ',
#  'Bear Trap                                         ',
#  'Bears Choice                                      ',
#  'Beasleys Face                                     ',
#  'Beast of Burden                                   ',
#  'Beat It                                           ',
#  'Beat Junkie                                       ',
#  'Beat me off Scottie                               ',
#  'Beaten Into Submission                            ',
#  'Beaten into Submission                            ',
#  'Beautiful Arete                                   ',
#  'Beautiful Freak                                   ',
#  'Beautiful Gecko                                   ',
#  'Beautiful People                                  ',
#  'Beautiful Soup                                    ',
#  'Beauty Face                                       ',
#  'Beauty School Dropout                             ',
#  'Beaver Cleaver                                    ',
#  'Beaver Fever                                      ',
#  'Beaver cleaver                                    ',
#  'Bebe Wolverine                                    ',
#  'Beckeys Problem                                   ',
#  'Becky Route                                       ',
#  'Bedtime for Bonzo                                 ',
#  'Bees Knees                                        ',
#  'Beef Cake                                         ',
#  'Beef It                                           ',
#  'Beef Stick                                        ',
#  'Beefy Gecko                                       ',
#  'Beefy gecko                                       ',
#  'Beehive Traverse                                  ',
#  'Been There, Done That                             ',
#  'Beer Belly                                        ',
#  'Beer Bong                                         ',
#  'Beer Can Traverse                                 ',
#  'Beer Quester                                      ',
#  'Beer Run                                          ',
#  'Beer Tumor                                        ',
#  'Beer Tumor Right                                  ',
#  'Beer Tumor right                                  ',
#  'Beer belly                                        ',
#  'Before The Storm                                  ',
#  'Beginners Luck                                    ',
#  'Begozi and the Ledge Lizards                      ',
#  'Behind the 8 Ball                                 ',
#  'Behind the Tree                                   ',
#  'Being Inferior                                    ',
#  'Being inferior                                    ',
#  'Believe It                                        ',
#  'Belly Button                                      ',
#  'Belly Flop                                        ',
#  'Belly Roll                                        ',
#  'Belly Rubber                                      ',
#  'Belly button                                      ',
#  'Belly of The Beast                                ',
#  'Belly of the Beast                                ',
#  'Belly of the beast                                ',
#  'Ben Dunne                                         ',
#  'Bens Arete                                        ',
#  'Bens Groove                                       ',
#  'Bens Reverse                                      ',
#  'Bens Roof                                         ',
#  'Bens Wall                                         ',
#  'Bens roof                                         ',
#  'Bens wall                                         ',
#  'Bench Wall                                        ',
#  'Beretta Extension                                 ',
#  'Bermuda Triangle                                  ',
#  'Bert Gives Good Blowjobs                          ',
#  'Best Problem in Minnesota                         ',
#  'Best Seat in the House                            ',
#  'Best in Show                                      ',
#  'Best of the Best                                  ',
#  'Best of the West                                  ',
#  'Beta Blocker                                      ',
#  'Beta Spewer                                       ',
#  'Beta blocker                                      ',
#  'Bettavul Pipeline                                 ',
#  'Better Beat Your Sweeties                         ',
#  'Better Eat Your Wheaties                          ',
#  'Better Than Coffee                                ',
#  'Better Than Starbucks                             ',
#  'Better beat your sweeties                         ',
#  'Better than Coffee                                ',
#  'Better than coffee                                ',
#  'Betty Bravo                                       ',
#  'Between the Cheeks                                ',
#  'Between the Sheets                                ',
#  'Beware of the Bear                                ',
#  'Beyond Berzerk                                    ',
#  'Beyond Life                                       ',
#  'Beyond Life Sit                                   ',
#  'Beyond Life sit                                   ',
#  'Beyond Matters                                    ',
#  'Beyond Reason                                     ',
#  'Beyond reason                                     ',
#  'Bicipital Groove                                  ',
#  'Bicycle Club                                      ',
#  'Bicycle Man                                       ',
#  'Big Air                                           ',
#  'Big Bad                                           ',
#  'Big Bad Boulder                                   ',
#  'Big Bad Left                                      ',
#  'Big Bad Right                                     ',
#  'Big Bad Wolf                                      ',
#  'Big Bear Memorial                                 ',
#  'Big Big Love                                      ',
#  'Big Black                                         ',
#  'Big Booty Bitch Slap                              ',
#  'Big Bopper                                        ',
#  'Big Boss Man                                      ',
#  'Big Boy                                           ',
#  'Big Bud                                           ',
#  'Big Burley                                        ',
#  'Big Calm                                          ',
#  'Big Cheesy                                        ',
#  'Big Chicken                                       ',
#  'Big City Boy                                      ',
#  'Big Daddy                                         ',
#  'Big Damage                                        ',
#  'Big Dick Jim                                      ',
#  'Big Dog                                           ',
#  'Big Eds Flying Saucer                             ',
#  'Big Greeny                                        ',
#  'Big Gulp                                          ',
#  'Big Guns                                          ',
#  'Big Hairy White Thing                             ',
#  'Big House                                         ',
#  'Big Iron On His Hip                               ',
#  'Big Iron on His Hip                               ',
#  'Big Joe                                           ',
#  'Big Joe Left                                      ',
#  'Big Jugs                                          ',
#  'Big K                                             ',
#  'Big Kahuna                                        ',
#  'Big Mac Regurgitator                              ',
#  'Big Mama                                          ',
#  'Big Man On Campus                                 ',
#  'Big Man on Campus                                 ',
#  'Big Marine                                        ',
#  'Big Medicine                                      ',
#  'Big Meech                                         ',
#  'Big Money Grip                                    ',
#  'Big Nose Milley                                   ',
#  'Big Overhang                                      ',
#  'Big Pocket Problem                                ',
#  'Big Poppa                                         ',
#  'Big Present                                       ',
#  'Big Red                                           ',
#  'Big Shot                                          ',
#  'Big Sinkin Breakdown                              ',
#  'Big Top                                           ',
#  'Big Up                                            ',
#  'Big Worm                                          ',
#  'Big Yellow Butterfly                              ',
#  'Big Zipper                                        ',
#  'Big greenie                                       ',
#  'Big guns                                          ',
#  'Big in Japan                                      ',
#  'Big iron on his hip                               ',
#  'Big joe                                           ',
#  'Bigger is Better                                  ',
#  'Biggie Shorty                                     ',
#  'Biggie Smalls                                     ',
#  'Biggie shorty                                     ',
#  'Bikini Amber                                      ',
#  'Bikini Atoll                                      ',
#  'Bikini Girls with Machine Guns                    ',
#  'Bikini Wax                                        ',
#  'Bill Murray                                       ',
#  'Bills Route                                       ',
#  'Bimbo Shrine                                      ',
#  'Bin Ladens Cave                                   ',
#  'Binous Crack                                      ',
#  'Bio Inflation                                     ',
#  'Biological Need                                   ',
#  'Bionic Rats                                       ',
#  'Bionic rats                                       ',
#  'Birch Tree Crack                                  ',
#  'Bird On A Wire                                    ',
#  'Bird of Fire                                      ',
#  'Bird of Paradise                                  ',
#  'Bird of Prey                                      ',
#  'Birds Nest                                        ',
#  'Birds of a Feather                                ',
#  'Birdshit Twister                                  ',
#  'Birth Rights                                      ',
#  'Birthday Direct                                   ',
#  'Birthday Left                                     ',
#  'Birthday Mantel                                   ',
#  'Birthday Skyline                                  ',
#  'Bisher Traverse                                   ',
#  'Bishops Terrace                                   ',
#  'Bitch Magnet                                      ',
#  'Bitch Slap                                        ',
#  'Bitch Slap 5                                      ',
#  'Bitch Slap Arete                                  ',
#  'Bitch Slap Left                                   ',
#  'Bitch slap                                        ',
#  'Bitches Brew                                      ',
#  'Bite the bullet                                   ',
#  'Bitter Bite                                       ',
#  'Bitter Ray of Sunshine                            ',
#  'Bitter and Twisted                                ',
#  'Black 45                                          ',
#  'Black Angus                                       ',
#  'Black Arete                                       ',
#  'Black Ball Retriever                              ',
#  'Black Bart                                        ',
#  'Black Boulder                                     ',
#  'Black Boulder Crack                               ',
#  'Black Boulder Layback                             ',
#  'Black Boulder Problem                             ',
#  'Black Carpet                                      ',
#  'Black Cauldron                                    ',
#  'Black Ceasar                                      ',
#  'Black Chipper Arete                               ',
#  'Black Corner                                      ',
#  'Black Corridor #4                                 ',
#  'Black Crack                                       ',
#  'Black Crow                                        ',
#  'Black Dahlia                                      ',
#  'Black Dog Crack                                   ',
#  'Black Elk                                         ',
#  'Black Face                                        ',
#  'Black Flag                                        ',
#  'Black Fly                                         ',
#  'Black Gold                                        ',
#  'Black Happy                                       ',
#  'Black Heart                                       ',
#  'Black Hole                                        ',
#  'Black Hole Sun                                    ',
#  'Black Ice                                         ',
#  'Black Jack Crack                                  ',
#  'Black Lassie                                      ',
#  'Black Lung                                        ',
#  'Black Magic                                       ',
#  'Black Magic Woman                                 ',
#  'Black Mamba                                       ',
#  'Black Matter                                      ',
#  'Black Monday                                      ',
#  'Black Moth Super Rainbow                          ',
#  'Black Nail                                        ',
#  'Black Plague                                      ',
#  'Black Planet                                      ',
#  'Black Powder                                      ',
#  'Black Prince                                      ',
#  'Black Problem                                     ',
#  'Black Rain                                        ',
#  'Black Roof                                        ',
#  'Black Russian                                     ',
#  'Black Sabbath                                     ',
#  'Black Sails                                       ',
#  'Black Scar                                        ',
#  'Black Sea                                         ',
#  'Black Sheep                                       ',
#  'Black Slab Left                                   ',
#  'Black Slab Left SDS                               ',
#  'Black Slab Right                                  ',
#  'Black Slab Right SDS                              ',
#  'Black Slabbath                                    ',
#  'Black Snake Moan                                  ',
#  'Black Snapper                                     ',
#  'Black Streak Dyno                                 ',
#  'Black Stripper                                    ',
#  'Black Swan                                        ',
#  'Black Thing                                       ',
#  'Black Tie Affair                                  ',
#  'Black Tornado                                     ',
#  'Black Widow                                       ',
#  'Black and Blue                                    ',
#  'Black and Tan                                     ',
#  'Black crow                                        ',
#  'Black snake moan                                  ',
#  'Black stripper                                    ',
#  'Blackmans Burden                                  ',
#  'Blade Loafer                                      ',
#  'Blade Runner                                      ',
#  'Blair Witch                                       ',
#  'Blank Canvas                                      ',
#  'Blank Frank                                       ',
#  'Blank Generation                                  ',
#  'Blank Out                                         ',
#  'Blankety Blank                                    ',
#  'Blankety Blank Sit                                ',
#  'Blasted Rock                                      ',
#  'Blasted Rock Crack                                ',
#  'Bleached Bones                                    ',
#  'Bleeding Brothers                                 ',
#  'Bleeding Lip Traverse                             ',
#  'Bleeding Me Out                                   ',
#  'Blessed and Blissed                               ',
#  'Blind Bat                                         ',
#  'Blind Date                                        ',
#  'Blind Faith                                       ',
#  'Blind Fig                                         ',
#  'Blind Spot                                        ',
#  'Blind as a Bat                                    ',
#  'Blind date                                        ',
#  'Blind in the Water                                ',
#  'Blinking Cowboy                                   ',
#  'Block Party                                       ',
#  'Block and Tackle                                  ',
#  'Block party                                       ',
#  'Blocky Horror Picture Show                        ',
#  'Blocky Matters                                    ',
#  'Blocky Start                                      ',
#  'Blok One                                          ',
#  'Blok Two                                          ',
#  'Blonde Ambition                                   ',
#  'Blood Bath                                        ',
#  'Blood Blister                                     ',
#  'Blood Brother                                     ',
#  'Blood Brothers                                    ',
#  'Blood Diamond                                     ',
#  'Blood Falls                                       ',
#  'Blood Money                                       ',
#  'Blood Raid                                        ',
#  'Blood Trails                                      ',
#  'Blood bath                                        ',
#  'Blood falls                                       ',
#  'Bloody Endeavor                                   ',
#  'Bloody Fingers                                    ',
#  'Bloody Flapper                                    ',
#  'Bloody Knuckles                                   ',
#  'Bloody Mary                                       ',
#  'Bloody Mushroom Stamp                             ',
#  'Bloody Sunday                                     ',
#  'Blow of Choss                                     ',
#  'Blow of Death                                     ',
#  'Blowin Loadz                                      ',
#  'Blowing Bubbles                                   ',
#  'Blowing Smoke At the Monkey                       ',
#  'Blowing Smoke at the Monkey                       ',
#  'Blowing the Gimp                                  ',
#  'Blown Away                                        ',
#  'Blue Angel                                        ',
#  'Blue Chunks                                       ',
#  'Blue Circles                                      ',
#  'Blue Collar                                       ',
#  'Blue Eyed                                         ',
#  'Blue Eyed Honkey Jesus                            ',
#  'Blue Flame                                        ',
#  'Blue Flowers                                      ',
#  'Blue Gramma                                       ',
#  'Blue Jet                                          ',
#  'Blue Justice                                      ',
#  'Blue Lambo                                        ',
#  'Blue Light Special                                ',
#  'Blue Mask                                         ',
#  'Blue Moon                                         ',
#  'Blue Ox                                           ',
#  'Blue Sling                                        ',
#  'Blue Spark                                        ',
#  'Blue Suede Shoes                                  ',
#  'Blue Sun                                          ',
#  'Blue Typhoon                                      ',
#  'Blue Velvet                                       ',
#  'Blue Whale                                        ',
#  'Blue and Black                                    ',
#  'Blue suede shoes                                  ',
#  'Blues Riff                                        ',
#  'Blunt Arete                                       ',
#  'Blunt Mentality                                   ',
#  'Blurred vision                                    ',
#  'Bo Cleevil                                        ',
#  'Boat People                                       ',
#  'Bob Barker                                        ',
#  'Bob Dylan Did Drugs                               ',
#  'Bob Marley                                        ',
#  'Bob Marley Meets Master Ganj                      ',
#  'Bobs Bulge                                        ',
#  'Bobs Dyno                                         ',
#  'Bobby Ds Bunny                                    ',
#  'Bobbys Problem                                    ',
#  'Bobcat Logic                                      ',
#  'Bodhi Day                                         ',
#  'Body Bag                                          ',
#  'Body Count                                        ',
#  'Body Dump                                         ',
#  'Body Glove                                        ',
#  'Body Hammer                                       ',
#  'Body Karate                                       ',
#  'Body Machine                                      ',
#  'Body Machine (from ground)                        ',
#  'Body Snap                                         ',
#  'Body Snap Sit                                     ',
#  'Body Spray                                        ',
#  'Body Wax                                          ',
#  'Body and Soul                                     ',
#  'Body snap sit                                     ',
#  'Bogey Man                                         ',
#  'Boing Boy                                         ',
#  'Bolt Action                                       ',
#  'Bolt From The Blue                                ',
#  'Bolt Revolt                                       ',
#  'Bolt Talk                                         ',
#  'Bolt and Run                                      ',
#  'Bolt line                                         ',
#  'Bolting Barbie                                    ',
#  'Bolts Not Bitches                                 ',
#  'Bolts not Bitches                                 ',
#  'Bomb Squad                                        ',
#  'Bon EZ                                            ',
#  'Bon Ez                                            ',
#  'Bon Voyage                                        ',
#  'Bone Crusher                                      ',
#  'Bone Machine                                      ',
#  'Bonehead Roof                                     ',
#  'Bong Thirty                                       ',
#  'Bongo Fury                                        ',
#  'Bongo fury                                        ',
#  'Bonnie and Clyde                                  ',
#  'Bonnies Roof                                      ',
#  'Bonsai Bulge                                      ',
#  'Boo Yaa                                           ',
#  'Boogey Wonderland                                 ',
#  'Boogie Man                                        ',
#  'Boogie Nights                                     ',
#  'Boogie Wonderland                                 ',
#  'Book of Condolences                               ',
#  'Book of Nightmares                                ',
#  'Book of nightmares                                ',
#  'Booka Booka Booka                                 ',
#  'Boone Lounge                                      ',
#  'Booney Project                                    ',
#  'Boot Boys Start                                   ',
#  'Boots with the Fur                                ',
#  'Booze Bottle Sit                                  ',
#  'Border Patrol Sit                                 ',
#  'Bored of Pies                                     ',
#  'Bored of the Lies                                 ',
#  'Bored of the lies                                 ',
#  'Born Again                                        ',
#  'Born Slappy                                       ',
#  'Born Under Punches                                ',
#  'Born in Blood                                     ',
#  'Born on the 4th of July                           ',
#  'Born to Drag                                      ',
#  'Boro Traverse                                     ',
#  'Bosley Traverse                                   ',
#  'Boss Hog                                          ',
#  'Boston Mess                                       ',
#  'Both Sides of the Spectrum                        ',
#  'Bottled Up Warrior                                ',
#  'Bottom Feeder                                     ',
#  'Bottoms Up                                        ',
#  'Boulder Basin Dyno                                ',
#  ...]

# %%
vocab = sorted(set(' '.join(route_names)))

# %%
ids_from_chars = preprocessing.StringLookup(vocabulary=list(vocab))
chars_from_ids = tf.keras.layers.experimental.preprocessing.StringLookup(
    vocabulary=ids_from_chars.get_vocabulary(),invert=True)

def text_from_ids(ids):
    return tf.strings.reduce_join(chars_from_ids(ids),axis=-1)

# %%
all_ids = ids_from_chars(tf.strings.unicode_split(route_names,'UTF-8'))

# %%
BATCH_SIZE = 50
ids_dataset = tf.data.Dataset.from_tensor_slices(all_ids)

# %%
def split_input_target(seq):
    return seq[:-1], seq[1:]

# %%
dataset = ids_dataset.map(split_input_target)

# %%
for a,b in dataset.take(1):
    print(a,b)
# Out:
# tf.Tensor(
# [ 5 16  2 27 70 57 72 57  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2
#   2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2
#   2], shape=(49,), dtype=int64) tf.Tensor(
# [16  2 27 70 57 72 57  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2
#   2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2  2
#   2], shape=(49,), dtype=int64)

# %%
dataset = dataset.shuffle(1000).batch(BATCH_SIZE).prefetch(tf.data.experimental.AUTOTUNE)

# %%
dataset
# Out:
# <PrefetchDataset shapes: ((None, None), (None, None)), types: (tf.int64, tf.int64)>

# %%
vocab_size = len(vocab)
embedding_dim = 256
rnn_units = 1024

# %%
class MyModel(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, rnn_units):
        super().__init__(self)
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(rnn_units,
                                       return_sequences=True,
                                       return_state=True)
        self.dense = tf.keras.layers.Dense(vocab_size)

    def call(self, inputs, states=None, return_state=False, training=False):
        x = inputs
        x = self.embedding(x, training=training)
        if states is None:
            states = self.gru.get_initial_state(x)
        x, states = self.gru(x, initial_state=states, training=training)
        x = self.dense(x, training=training)

        if return_state:
            return x, states
        else:
            return x

# %%
model = MyModel(vocab_size=len(ids_from_chars.get_vocabulary()),
                  embedding_dim = embedding_dim,
                  rnn_units = rnn_units)

# %%
loss = tf.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(optimizer='adam', loss=loss)

# %%
# Directory where the checkpoints will be saved
checkpoint_dir = './training_checkpoints'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True)

EPOCHS = 30
last_model_cpt = checkpoint_dir+f"/ckpt_{EPOCHS}.data-00000-of-00001"
if os.path.exists(last_model_cpt):
    latest = tf.train.latest_checkpoint(checkpoint_dir)
    model.load_weights(latest)
else:
    history = model.fit(dataset, epochs=EPOCHS, callbacks=[checkpoint_callback])
# Out:
# ./training_checkpoints/ckpt_30

# %%
class OneStep(tf.keras.Model):
  def __init__(self, model, chars_from_ids, ids_from_chars, temperature=1.0):
    super().__init__()
    self.temperature=temperature
    self.model = model
    self.chars_from_ids = chars_from_ids
    self.ids_from_chars = ids_from_chars

    # Create a mask to prevent "" or "[UNK]" from being generated.
    skip_ids = self.ids_from_chars(['','[UNK]'])[:, None]
    sparse_mask = tf.SparseTensor(
        # Put a -inf at each bad index.
        values=[-float('inf')]*len(skip_ids),
        indices = skip_ids,
        # Match the shape to the vocabulary
        dense_shape=[len(ids_from_chars.get_vocabulary())]) 
    self.prediction_mask = tf.sparse.to_dense(sparse_mask)

  @tf.function
  def generate_one_step(self, inputs, states=None):
    # Convert strings to token IDs.
    input_chars = tf.strings.unicode_split(inputs, 'UTF-8')
    input_ids = self.ids_from_chars(input_chars).to_tensor()

    # Run the model.
    # predicted_logits.shape is [batch, char, next_char_logits] 
    predicted_logits, states =  self.model(inputs=input_ids, states=states, 
                                          return_state=True)
    # Only use the last prediction.
    predicted_logits = predicted_logits[:, -1, :]
    predicted_logits = predicted_logits/self.temperature
    # Apply the prediction mask: prevent "" or "[UNK]" from being generated.
    predicted_logits = predicted_logits + self.prediction_mask

    # Sample the output logits to generate token IDs.
    predicted_ids = tf.random.categorical(predicted_logits, num_samples=1)
    predicted_ids = tf.squeeze(predicted_ids, axis=-1)

    # Convert from token ids to characters
    predicted_chars = self.chars_from_ids(predicted_ids)

    # Return the characters and model state.
    return predicted_chars, states

# %%
one_step_model = OneStep(model, chars_from_ids, ids_from_chars)

# %%
start = time.time()
states = None
next_char = tf.constant(['S'])
result = [next_char]

res = route_names[0]
while res in route_names:
    for n in range(49):
        next_char, states = one_step_model.generate_one_step(next_char, states=states)
        result.append(next_char)

    result = tf.strings.join(result)

    res = result[0].numpy().decode('utf-8')
    
    result = [next_char]
    print(res)
# Out:
# Soul One

# %%
res in route_names
# Out:
# False
